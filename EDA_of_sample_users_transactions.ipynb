# %% [markdown]
# # Import Data and Required Packages
#
# Importing Pandas, Numpy, Matplotlib, Seaborn and Warings Library.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Import the Data as Pandas DataFrame

# %%
df = pd.read_parquet('sample_users_transactions.parquet').to_csv('trans.csv')

# %%
df3 = pd.read_parquet('sample_users_transactions.parquet')
df3
# Out:
#          trans_id  trans_user_id                             trans_name  \
# 0        50187184         764849       ZEL*CAFE GONZALES CAFE Atlanta G
# 1        50187185         764849       Garuda Labs, Inc. San FranciscoC
# 2        50187186         764849                ATM BALANCE INQUIRY FEE
# 3        50187187         764849                         WITHDRAWAL FEE
# 4        50187188         764849                                  Shell
# ...           ...            ...                                    ...
# 2208141  62860076         750224                  +16506819470, CA, USA
# 2208142  62860077         750224                 San Francisco, CA, USA
# 2208143  62860078         750224                         ESSEX, MD, USA
# 2208144  62860079         750224  CATONSVILLE CRO Cantonsville, MD, USA
# 2208145  62860080         750224                     BALTIMORE, MD, USA
#
#          trans_amount  trans_after_balance  trans_date  \
# ...

# %% [markdown]
# # Show Top 5 Records

# %%
df3.head()
# Out:
#    trans_id  trans_user_id                        trans_name  trans_amount  \
# 0  50187184         764849  ZEL*CAFE GONZALES CAFE Atlanta G        -12.00
# 1  50187185         764849  Garuda Labs, Inc. San FranciscoC       -165.00
# 2  50187186         764849           ATM BALANCE INQUIRY FEE          1.50
# 3  50187187         764849                    WITHDRAWAL FEE          2.50
# 4  50187188         764849                             Shell         29.02
#
#    trans_after_balance  trans_date trans_personal_category  \
# 0             -2168.90  2022-01-19          FOOD_AND_DRINK
# 1             -2003.90  2022-01-19             TRANSFER_IN
# 2             -2005.40  2022-01-19               BANK_FEES
# 3             -2007.90  2022-01-20               BANK_FEES
# 4             -2036.92  2022-01-20          TRANSPORTATION
#
#      trans_personal_cat_details    trans_created_at
# 0     FOOD_AND_DRINK_RESTAURANT 2022-05-30 04:56:54
# 1  TRANSFER_IN_ACCOUNT_TRANSFER 2022-05-30 04:56:54
# ...

# %% [markdown]
# # Shape of the dataset

# %%
df3.shape
# Out:
# (2208146, 9)

# %% [markdown]
# # Dataset information
# 1.	trans_id: - unique transaction id
# 2.	trans_user_id: - unqiue user identifier
# 3.	trans_name: - transaction name
# 4.	trans_amount: - transaction amount (if amount <0 then credit else debit)
# 5.	trans_afte_balance: - account balance after transactions completed
# 6.	trans_date: - transaction date
# 7.	trans_personal_category: - transactions main category
# 8.	trans_persoanl_cat_details: - transactions sub category
# 9.	trans_created_at: - transactions stored time in DB

# %% [markdown]
# # Data Checks to perform

# %% [markdown]
# Check Missing values

# %%
df3.isna().sum()
# Out:
# trans_id                      0
# trans_user_id                 0
# trans_name                    0
# trans_amount                  0
# trans_after_balance           0
# trans_date                    0
# trans_personal_category       7
# trans_personal_cat_details    7
# trans_created_at              0
# dtype: int64

# %% [markdown]
# There are some missing values in
# transactions main category and transactions sub category

# %% [markdown]
# Check Duplicates

# %%
df3.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicates values in the data set

# %% [markdown]
# Check data types

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2208146 entries, 0 to 2208145
# Data columns (total 9 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   trans_id                    int64
#  1   trans_user_id               int64
#  2   trans_name                  object
#  3   trans_amount                float64
#  4   trans_after_balance         float64
#  5   trans_date                  object
#  6   trans_personal_category     object
#  7   trans_personal_cat_details  object
#  8   trans_created_at            datetime64[us]
# dtypes: datetime64[us](1), float64(2), int64(2), object(4)
# memory usage: 151.6+ MB

# %% [markdown]
# Checking the number of unique values of each column

# %%
df3.nunique()
# Out:
# trans_id                      2208146
# trans_user_id                    3900
# trans_name                    1128704
# trans_amount                    94099
# trans_after_balance            457377
# trans_date                        200
# trans_personal_category            18
# trans_personal_cat_details         98
# trans_created_at                13146
# dtype: int64

# %% [markdown]
# Check statistics of data

# %%
df3.describe()
# Out:
#            trans_id  trans_user_id  trans_amount  trans_after_balance  \
# count  2.208146e+06   2.208146e+06  2.208146e+06         2.208146e+06
# mean   3.214997e+07   6.771858e+05  6.698291e-01         6.243536e+02
# min    3.975713e+06   2.550500e+04 -1.625310e+05        -7.760880e+04
# 25%    2.359480e+07   7.038490e+05  2.340000e+00         3.377000e+01
# 50%    2.530909e+07   7.301280e+05  1.296000e+01         2.692600e+02
# 75%    4.223111e+07   7.430670e+05  3.789000e+01         8.164300e+02
# max    6.437814e+07   7.861890e+05  2.320000e+05         2.792930e+05
# std    1.185094e+07   1.442522e+05  4.573292e+02         2.293517e+03
#
#                  trans_created_at
# count                     2208146
# mean   2022-05-22 10:24:31.199818
# min           2022-05-19 04:58:05
# 25%           2022-05-19 12:15:46
# 50%           2022-05-19 14:01:01
# 75%           2022-05-23 23:34:17
# max           2022-06-10 06:36:58
# std                           NaN

# %%
df3.head()
# Out:
#    trans_id  trans_user_id                        trans_name  trans_amount  \
# 0  50187184         764849  ZEL*CAFE GONZALES CAFE Atlanta G        -12.00
# 1  50187185         764849  Garuda Labs, Inc. San FranciscoC       -165.00
# 2  50187186         764849           ATM BALANCE INQUIRY FEE          1.50
# 3  50187187         764849                    WITHDRAWAL FEE          2.50
# 4  50187188         764849                             Shell         29.02
#
#    trans_after_balance  trans_date trans_personal_category  \
# 0             -2168.90  2022-01-19          FOOD_AND_DRINK
# 1             -2003.90  2022-01-19             TRANSFER_IN
# 2             -2005.40  2022-01-19               BANK_FEES
# 3             -2007.90  2022-01-20               BANK_FEES
# 4             -2036.92  2022-01-20          TRANSPORTATION
#
#      trans_personal_cat_details    trans_created_at
# 0     FOOD_AND_DRINK_RESTAURANT 2022-05-30 04:56:54
# 1  TRANSFER_IN_ACCOUNT_TRANSFER 2022-05-30 04:56:54
# ...

# %%
plt.figure(figsize = (10, 7))

df3.boxplot()
# Out:
# <Axes: >

# %%
df3.boxplot('trans_amount','trans_after_balance')

# %% [markdown]
# trans_amount,trans_after_balance columns has outliers.
