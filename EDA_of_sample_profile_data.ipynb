# %% [markdown]
# Import Data and Required Packages
#
# Importing Pandas, Numpy, Matplotlib, Seaborn and Warings Library.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Import the Excel Data as Pandas DataFrame

# %%
df1 = pd.read_excel('sample_profile_data.xlsx')
df1
# Out:
#       profile_user_id profile_birth_date profile_city profile_residence_state  \
# 0               50620         1982-03-21   Villa Rica                 Georgia
# 1               51262         1966-06-02       Okemos                Michigan
# 2               63276         1993-10-07       beaver                    Utah
# 3               63281         1991-08-15       Sumter          South Carolina
# 4               65404                NaT          NaN                   Texas
# ...               ...                ...          ...                     ...
# 3880           784112                NaT          NaN                Illinois
# 3881           784712         2022-06-03          NaN                New York
# 3882           784988         1997-05-02       Salina                  Kansas
# 3883           786116         2022-06-02          NaN              Washington
# 3884           786189                NaT          NaN                Michigan
#
#      profile_registerd_device
# ...

# %% [markdown]
# Show Top 5 Records

# %%
df1.head()
# Out:
#    profile_user_id profile_birth_date profile_city profile_residence_state  \
# 0            50620         1982-03-21   Villa Rica                 Georgia
# 1            51262         1966-06-02       Okemos                Michigan
# 2            63276         1993-10-07       beaver                    Utah
# 3            63281         1991-08-15       Sumter          South Carolina
# 4            65404                NaT          NaN                   Texas
#
#   profile_registerd_device
# 0                      ios
# 1                      ios
# 2                      ios
# 3                      ios
# 4                      ios

# %% [markdown]
# Shape of the dataset

# %%
df1.shape
# Out:
# (3885, 5)

# %% [markdown]
# #Dataset information
# 1.	profile_user_id: - unique user identifier
# 2.	profile_birth_date: - user birth date
# 3.	profile_city: - user residing city
# 4.	profile_residence_state: - user residing state
# 5.	profile_registerd_device: - user registered device whether IOS and Android

# %% [markdown]
# # Data Checks to perform
#
# Check Missing values
#
# Check Duplicates
#
# Check data type
#
# Check the number of unique values of each column
#
# Check statistics of data set
#
# Check various categories present in the different
#
#  categorical column

# %% [markdown]
# # Check Missing values

# %%
df1.isna().sum()
# Out:
# profile_user_id                0
# profile_birth_date          2261
# profile_city                2435
# profile_residence_state       25
# profile_registerd_device       0
# dtype: int64

# %% [markdown]
# There are some missing values in the data set

# %% [markdown]
# # Check Duplicates

# %%
df1.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicates values in the data set

# %% [markdown]
# # Check data types

# %%
# Check Null and Dtypes
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3885 entries, 0 to 3884
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   profile_user_id           3885 non-null   int64
#  1   profile_birth_date        1624 non-null   datetime64[ns]
#  2   profile_city              1450 non-null   object
#  3   profile_residence_state   3860 non-null   object
#  4   profile_registerd_device  3885 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 151.9+ KB

# %% [markdown]
# # Checking the number of unique values of each column

# %%
df1.nunique()
# Out:
# profile_user_id             3885
# profile_birth_date          1248
# profile_city                1015
# profile_residence_state       53
# profile_registerd_device       2
# dtype: int64

# %% [markdown]
# # Check statistics of data

# %%
df1.describe()
# Out:
#        profile_user_id             profile_birth_date
# count      3885.000000                           1624
# mean     678165.008752  1995-08-29 03:32:48.472906368
# min       50620.000000            1926-11-22 00:00:00
# 25%      703530.000000            1984-10-28 06:00:00
# 50%      730091.000000            1992-10-31 12:00:00
# 75%      742759.000000            2002-01-15 06:00:00
# max      786189.000000            2022-09-18 00:00:00
# std      140662.082868                            NaN

# %% [markdown]
# # Exploring Data

# %%
df1.head()
# Out:
#    profile_user_id profile_birth_date profile_city profile_residence_state  \
# 0            50620         1982-03-21   Villa Rica                 Georgia
# 1            51262         1966-06-02       Okemos                Michigan
# 2            63276         1993-10-07       beaver                    Utah
# 3            63281         1991-08-15       Sumter          South Carolina
# 4            65404                NaT          NaN                   Texas
#
#   profile_registerd_device
# 0                      ios
# 1                      ios
# 2                      ios
# 3                      ios
# 4                      ios

# %%
print("Categories in 'profile_city' variable:     ",end=" " )
print(df1['profile_city'].unique())
print('Total count: ',df1['profile_city'].nunique())
print('------------------------------------------------------------------')

print("Categories in 'profile_residence_state' variable:     ",end=" " )
print(df1['profile_residence_state'].unique())
print('Total count: ',df1['profile_residence_state'].nunique())
print('------------------------------------------------------------------')

print("Categories in 'profile_registerd_device' variable:     ",end=" " )
print(df1['profile_registerd_device'].unique())
print('Total count: ',df1['profile_registerd_device'].nunique())
print('------------------------------------------------------------------')
# Out:
# Categories in 'profile_city' variable:      ['Villa Rica' 'Okemos' 'beaver' ... 'Riverdale' 'ithaca' 'Salina']
# Total count:  1015
# ------------------------------------------------------------------
# Categories in 'profile_residence_state' variable:      ['Georgia' 'Michigan' 'Utah' 'South Carolina' 'Texas' 'New York'
#  'California' 'Florida' 'Alabama' 'Ohio' 'Arizona' 'Illinois' 'Maryland'
#  'Massachusetts' 'Louisiana' 'New Jersey' 'Virginia' 'Pennsylvania'
#  'Nevada' 'Washington' 'Colorado' 'Nebraska' 'North Carolina'
#  'West Virginia' 'Delaware' 'Mississippi' 'District Of Columbia'
#  'Oklahoma' 'Indiana' 'Montana' 'Tennessee' 'Kentucky' 'Minnesota'
#  'Missouri' 'Arkansas' 'New Hampshire' 'Kansas' 'Iowa' 'New Mexico'
#  'Maine' 'Connecticut' 'Wisconsin' 'Oregon' 'Alaska' 'Idaho'
#  'South Dakota' nan 'Hawaii' 'Wyoming' 'Rhode Island' 'NC' 'North Dakota'
#  'Vermont' 'Puerto Rico']
# Total count:  53
# ------------------------------------------------------------------
# ...

# %%
# define numerical & categorical columns
numeric_features = [feature for feature in df1.columns if df1[feature].dtype != 'O']
categorical_features = [feature for feature in df1.columns if df1[feature].dtype == 'O']

# print columns
print('We have {} numerical features : {}'.format(len(numeric_features), numeric_features))
print('\nWe have {} categorical features : {}'.format(len(categorical_features), categorical_features))
# Out:
# We have 2 numerical features : ['profile_user_id', 'profile_birth_date']
#
# We have 3 categorical features : ['profile_city', 'profile_residence_state', 'profile_registerd_device']

# %%
df1.head()
# Out:
#    profile_user_id profile_birth_date profile_city profile_residence_state  \
# 0            50620         1982-03-21   Villa Rica                 Georgia
# 1            51262         1966-06-02       Okemos                Michigan
# 2            63276         1993-10-07       beaver                    Utah
# 3            63281         1991-08-15       Sumter          South Carolina
# 4            65404                NaT          NaN                   Texas
#
#   profile_registerd_device
# 0                      ios
# 1                      ios
# 2                      ios
# 3                      ios
# 4                      ios

# %%
# @title profile_registerd_device


df1.groupby('profile_registerd_device').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)
print('Value count: ',df1['profile_registerd_device'].value_counts())
# Out:
# Value count:  profile_registerd_device
# ios        3322
# android     563
# Name: count, dtype: int64

# %% [markdown]
# There are 3322 ios registerd devices and 563 android registerd device.
#
# Ios registerd devices is more than android registerd device

# %% [markdown]
# # profile_city

# %%
print('Value count: ',df1['profile_city'].value_counts())
# Out:
# Value count:  profile_city
# Houston         27
# Brooklyn        14
# Philadelphia    14
# San Antonio     13
# Columbus        11
#                 ..
# Taylors          1
# hillsborough     1
# Taylorsville     1
# Pryor2           1
# Salina           1
# Name: count, Length: 1015, dtype: int64

# %% [markdown]
# Highest profile city is houston with 27 user's

# %%
print('Value count: ',df1['profile_residence_state'].value_counts())
# Out:
# Value count:  profile_residence_state
# Texas                   474
# California              404
# Florida                 355
# Georgia                 202
# New York                197
# Ohio                    156
# Illinois                137
# North Carolina          126
# Pennsylvania            120
# Virginia                118
# Arizona                 117
# New Jersey              102
# South Carolina           93
# Michigan                 89
# Alabama                  88
# Maryland                 84
# Tennessee                75
# Washington               72
# Louisiana                72
# Indiana                  65
# Nevada                   62
# Colorado                 62
# Missouri                 58
# Massachusetts            46
# Kentucky                 44
# Mississippi              43
# Minnesota                39
# Connecticut              31
# Arkansas                 30
# Oregon                   30
# Kansas                   26
# Wisconsin                24
# ...

# %% [markdown]
# There are highest value residence city is Texas

# %%
plt.figure(figsize = (10, 7))

df1.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# profile user id column has outliers.
