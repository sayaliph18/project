# %% [markdown]
# Import Data and Required Packages
#
#
# Importing Pandas, Numpy, Matplotlib, Seaborn and Warings Library.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Import the CSV Data as Pandas DataFrame

# %%
df2 = pd.read_csv('sample_loan_data.csv')
df2
# Out:
#       loan_id  loan_user_id  loan_amount loan_repay_date  \
# 0      489447        724848         20.0      2022-05-30
# 1      489448        601624         15.0      2022-05-30
# 2      489450        724851         75.0      2022-05-30
# 3      489455        588557         15.0      2022-05-30
# 4      489456        724887         20.0      2022-05-30
# ...       ...           ...          ...             ...
# 3895   532340        784712        140.0      2022-06-07
# 3896   532535        784988         15.0      2022-07-01
# 3897   533353        786116         20.0      2022-07-02
# 3898   533443        786189         30.0      2022-07-03
# 3899   533951        780960         35.0      2022-06-10
#
#      loan_repay_extended_date  loan_status      loan_created_at
# 0                         NaN            2  2022-05-01 00:03:50
# 1                         NaN            7  2022-05-01 00:04:05
# 2                         NaN            2  2022-05-01 00:06:24
# ...

# %% [markdown]
# #Show Top 5 Records

# %%
df2.head()
# Out:
#    loan_id  loan_user_id  loan_amount loan_repay_date  \
# 0   489447        724848         20.0      2022-05-30
# 1   489448        601624         15.0      2022-05-30
# 2   489450        724851         75.0      2022-05-30
# 3   489455        588557         15.0      2022-05-30
# 4   489456        724887         20.0      2022-05-30
#
#   loan_repay_extended_date  loan_status      loan_created_at
# 0                      NaN            2  2022-05-01 00:03:50
# 1                      NaN            7  2022-05-01 00:04:05
# 2                      NaN            2  2022-05-01 00:06:24
# 3                      NaN            7  2022-05-01 00:12:08
# 4                      NaN            7  2022-05-01 00:19:59

# %% [markdown]
# # Shape of the dataset

# %%
df2.shape
# Out:
# (3900, 7)

# %% [markdown]
# # Dataset information
# 1.	loan_id: - unique loan identifier
# 2.	loan_user_id: - unique loan user identifier
# 3.	loan_amount: - given loan amount
# 4.	loan_repay_date: - user loan repayment date
# 5.	loan_repay_extended_date: - user loan repayment extended date (can be null if user did not take extension)
# 6.	loan_status: - status of the loan
# a.	loans_status=2 -> loan got paid by the user
# b.	loan_status=7-> loan got defaulted
# 7.	laon_created_at: - loan given time

# %% [markdown]
# # Data Checks to perform
#
# Check Missing values
#
# Check Duplicates
#
# Check data type
#
# Check the number of unique values of each column
#
# Check statistics of data set
#
# Check various categories present in the different
#
# categorical column

# %% [markdown]
# # Check Missing values

# %%
df2.isna().sum()
# Out:
# loan_id                        0
# loan_user_id                   0
# loan_amount                    0
# loan_repay_date                0
# loan_repay_extended_date    3756
# loan_status                    0
# loan_created_at                0
# dtype: int64

# %% [markdown]
# For loan_repay_extended_date feature we have total 3756 missing Values.

# %% [markdown]
# # Check duplicate values

# %%
df2.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicates values in the data set

# %% [markdown]
# # Check data types

# %%
# Check Null and Dtypes
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   loan_id                   3900 non-null   int64
#  1   loan_user_id              3900 non-null   int64
#  2   loan_amount               3900 non-null   float64
#  3   loan_repay_date           3900 non-null   object
#  4   loan_repay_extended_date  144 non-null    object
#  5   loan_status               3900 non-null   int64
#  6   loan_created_at           3900 non-null   object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 213.4+ KB

# %% [markdown]
# # Checking the number of unique values of each column

# %%
df2.nunique()
# Out:
# loan_id                     3900
# loan_user_id                3900
# loan_amount                   14
# loan_repay_date               59
# loan_repay_extended_date      34
# loan_status                    2
# loan_created_at             3891
# dtype: int64

# %% [markdown]
# # Check statistics of data

# %%
df2.describe()
# Out:
#              loan_id   loan_user_id  loan_amount  loan_status
# count    3900.000000    3900.000000  3900.000000  3900.000000
# mean   501355.814872  675702.548462    44.203846     2.911538
# std     10895.502818  145879.211931    34.678211     1.930737
# min    489447.000000   25505.000000    15.000000     2.000000
# 25%    492688.250000  701491.500000    20.000000     2.000000
# 50%    497179.500000  730036.000000    35.000000     2.000000
# 75%    508050.000000  742500.000000    55.000000     2.000000
# max    533951.000000  786189.000000   200.000000     7.000000

# %%
# define numerical & categorical columns
numeric_features = [feature for feature in df2.columns if df2[feature].dtype != 'O']
categorical_features = [feature for feature in df2.columns if df2[feature].dtype == 'O']

# print columns
print('We have {} numerical features : {}'.format(len(numeric_features), numeric_features))
print('\nWe have {} categorical features : {}'.format(len(categorical_features), categorical_features))
# Out:
# We have 4 numerical features : ['loan_id', 'loan_user_id', 'loan_amount', 'loan_status']
#
# We have 3 categorical features : ['loan_repay_date', 'loan_repay_extended_date', 'loan_created_at']

# %%
df2.head()
# Out:
#    loan_id  loan_user_id  loan_amount loan_repay_date  \
# 0   489447        724848         20.0      2022-05-30
# 1   489448        601624         15.0      2022-05-30
# 2   489450        724851         75.0      2022-05-30
# 3   489455        588557         15.0      2022-05-30
# 4   489456        724887         20.0      2022-05-30
#
#   loan_repay_extended_date  loan_status      loan_created_at
# 0                      NaN            2  2022-05-01 00:03:50
# 1                      NaN            7  2022-05-01 00:04:05
# 2                      NaN            2  2022-05-01 00:06:24
# 3                      NaN            7  2022-05-01 00:12:08
# 4                      NaN            7  2022-05-01 00:19:59

# %%
# @title loan_status

from matplotlib import pyplot as plt
df2['loan_status'].plot(kind='hist', bins=20, title='loan_status')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# Rate of loan paid by user is high compare to loan got defaulted.

# %%
# @title loan_amount

from matplotlib import pyplot as plt
df2['loan_amount'].plot(kind='hist', bins=20, title='loan_amount')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# There are highest loan amount between 15 to 75

# %%
sns.pairplot(data=df2)

# %%
plt.figure(figsize = (10, 7))

df2.boxplot()
# Out:
# <Axes: >

# %%
df2.boxplot('loan_amount','loan_status')
# Out:
# <Axes: title={'center': 'loan_amount'}, xlabel='loan_status'>

# %%
df2.boxplot('loan_amount')
# Out:
# <Axes: >

# %% [markdown]
# loan amount,loan user id column has outliers.
